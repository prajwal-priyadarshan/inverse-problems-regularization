# %%
import json
import pandas as pd
from pathlib import Path

root = Path(__file__).resolve().parents[1]
metrics_dir = root / 'results' / 'metrics'
mse_df = pd.read_csv(metrics_dir / 'mse_results.csv')
psnr_df = pd.read_csv(metrics_dir / 'psnr_results.csv')
summary_medium = json.loads((metrics_dir / 'summary_medium.json').read_text())
mse_df.head(), summary_medium['best_tikhonov'], summary_medium['best_tsvd']

# %% [markdown]
# ## Notes
# - Use `mse_df` / `psnr_df` to rank methods across noise levels.
# - Best configs per noise level are stored in the summary JSONs.
# - Figures already saved in results/figures/.
